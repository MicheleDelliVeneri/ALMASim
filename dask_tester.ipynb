# %%
import dask
from dask.distributed import Client, progress
import simulator as sm
import numpy as np
import pandas as pd 
client = Client(threads_per_worker=4, n_workers=10)
client
# Out:
# /home/deepfocus/anaconda3/envs/casa6.5/lib/python3.8/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 34879 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:44738' processes=10 threads=40, memory=865.95 GiB>

# %%
import pandas as pd

# %%
idxs = np.arange(0, 10)
data_dir = ['/media/storage' for i in idxs]
main_path = ['/home/deepfocus/ALMASim' for i in idxs]
output_dir = ['sims' for i in idxs]
project_name = ['sim' for i in idxs]
bands = np.random.randint(3, 6, size=len(idxs))
antenna_name = ['alma.cycle9.3.3' for i in idxs]
inbright = [0.001 for i in idxs]
bandwidth  = [1280 for i in idxs]
inwidth = [10 for i in idxs]
integration = [10 for i in idxs]
totaltime = [2500 for i in idxs]
pwv = 0.5 * np.random.sample(size=len(idxs))
snr = np.random.randint(10, 30, size=len(idxs))
get_skymodel = [False for i in idxs]
extended = [False for i in idxs]
plot = [True for i in idxs]

input_params = pd.DataFrame(zip(idxs, data_dir, main_path, output_dir, project_name, bands, antenna_name, inbright, bandwidth, inwidth, integration, totaltime, pwv, snr, get_skymodel, extended, plot), columns=['idx', 'data_dir', 'main_path', 'output_dir', 'project_name', 'bands', 'antenna_name', 'inbright', 'bandwidth', 'inwidth', 'integration', 'totaltime', 'pwv', 'snr', 'get_skymodel', 'extended', 'plot'])
input_params.info()
futures = client.map(sm.simulator, input_params.values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   idx           10 non-null     int64
#  1   data_dir      10 non-null     object
#  2   main_path     10 non-null     object
#  3   output_dir    10 non-null     object
#  4   project_name  10 non-null     object
#  5   bands         10 non-null     int64
#  6   antenna_name  10 non-null     object
#  7   inbright      10 non-null     float64
#  8   bandwidth     10 non-null     int64
#  9   inwidth       10 non-null     int64
#  10  integration   10 non-null     int64
#  11  totaltime     10 non-null     int64
#  12  pwv           10 non-null     float64
#  13  snr           10 non-null     int64
#  14  get_skymodel  10 non-null     bool
#  15  extended      10 non-null     bool
#  16  plot          10 non-null     bool
# dtypes: bool(3), float64(2), int64(7), object(5)
# memory usage: 1.2+ KB
# [0 '/media/storage' '/home/deepfocus/ALMASim' 'sims' 'sim' 5
#  'alma.cycle9.3.3' 0.001 1280 10 10 2500 0.26843954261501923 19 False
#  False True]
